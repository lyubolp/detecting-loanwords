# %%
import matplotlib.pyplot as plt

# %%
train_loss = [0.525, 0.082, 0.048, 0.036,0.029, 0.025, 0.022, 0.020, 0.018, 0.017, 0.016, 0.015, 
0.015, 0.014, 0.013, 0.013, 0.013, 0.013,0.012, 0.012, 0.012, 0.012, 0.012, 0.011, 0.011]

val_loss = [0.102, 0.055, 0.043, 0.037, 0.034, 0.032, 0.030, 0.030, 0.028, 0.027, 0.026, 0.027, 
0.026, 0.026, 0.026, 0.025, 0.025, 0.025, 0.026, 0.024, 0.025, 0.026, 0.025, 0.025, 0.024]

plt.plot(train_loss, label='Training loss')
plt.plot(val_loss, label='Validation loss')

# Adding labels and title
plt.xlabel('Епохи')
plt.ylabel('Loss')

# Adding legend
plt.legend()

# Display the plot
plt.show()
